# %% [markdown]
# # Índice de contenidos
# 1. Antes de empezar
#
# 2. Reto 1 - Explorar el conjunto de datos
#
#     2.0.0.1 Explore los datos a vista de pájaro.
#
#     2.0.0.2 A continuación, evalúe si las columnas de este conjunto de datos están fuertemente correlacionadas.
#
# 3. Reto 2 - Eliminar la colinealidad de columnas.
#
# 4. Reto 3 - Manejar los valores perdidos
#
#     4.0.0.1 En las celdas siguientes, trate los valores que faltan en el conjunto de datos. Recuerde comentar los fundamentos de sus decisiones.
#
#     4.0.0.2 De nuevo, examine el número de valores que faltan en cada columna.
#
# 5. Reto 4 - Manejo de datos categóricos WHOIS_*
#
#     5.0.0.1 En las celdas siguientes, fije los valores de los países como se ha indicado anteriormente.
#
#     5.0.0.2 Si un número limitado de valores representa la mayoría de los datos, podemos conservar estos valores principales y volver a etiquetar todos los demás valores poco frecuentes.
#
#     5.0.0.3 Después de comprobarlo, mantengamos los 10 valores principales de la columna y reetiquetemos las demás columnas con OTROS.
#
#     5.0.0.4 En la siguiente celda, elimine ['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE'].
#
# 6. Reto 5 - Manejar los datos categóricos restantes y convertirlos en ordinales
#
#     6.0.0.1 URL es fácil. Simplemente la eliminaremos porque tiene demasiados valores únicos que no hay forma de consolidar.
#
#     6.0.0.2 Imprima el conteo de valores únicos de CHARSET. Puede ver que sólo hay unos pocos valores únicos. Así que podemos dejarlo como está.
#
#     6.0.0.3 Antes de pensar en su propia solución, no lea las instrucciones que vienen a continuación.
#
# 7. Desafío 6 - Modelado, predicción y evaluación
#
#     7.0.0.1 En este laboratorio probaremos dos modelos diferentes y compararemos nuestros resultados.
#
#     7.0.0.2 Nuestro segundo algoritmo es DecisionTreeClassifier.
#
#     7.0.0.3 Crearemos otro modelo DecisionTreeClassifier con max_depth=5.
#
# 8. Bonus Challenge - Escalado de características

# %% [markdown]
# # Antes de empezar:
# - Lee el archivo README.md
# - Comenta todo lo que puedas y utiliza los recursos del archivo README.md
# - ¡Feliz aprendizaje!

# %%
# Import your libraries:

# %matplotlib inline

import numpy as np
import pandas as pd

# %% [markdown]
# En este laboratorio, exploraremos un conjunto de datos que describe sitios web con diferentes características y los etiqueta como benignos o maliciosos. Utilizaremos algoritmos de aprendizaje supervisado para averiguar qué patrones de características es probable que tengan los sitios web maliciosos y utilizaremos nuestro modelo para predecir sitios web maliciosos.
#
# Sus características serán:
#
# + URL: es la identificación anónima de la URL analizada en el estudio
# + URL_LENGTH: es el número de caracteres de la URL
# + NUMBER_SPECIAL_CHARACTERS: es el número de caracteres especiales identificados en la URL, como, «/», «%», «#», «&», «. “, ”=»
# + CHARSET: es un valor categórico y su significado es el estándar de codificación de caracteres (también llamado juego de caracteres).
# + SERVER: es un valor categórico y su significado es el sistema operativo del servidor obtenido de la respuesta del paquete.
# + CONTENT_LENGTH: representa el tamaño del contenido de la cabecera HTTP.
# + WHOIS_COUNTRY: es una variable categórica, sus valores son los países que obtuvimos de la respuesta del servidor (en concreto, nuestro script utilizó la API de Whois).
# + WHOIS_STATEPRO: es una variable categórica, sus valores son los estados que obtuvimos de la respuesta del servidor (en concreto, nuestro script utilizó la API de Whois).
# + WHOIS_REGDATE: Whois proporciona la fecha de registro del servidor, por tanto, esta variable tiene valores de fecha con formato DD/MM/AAAA HH:MM
# + WHOIS_UPDATED_DATE: A través del Whois obtenemos la última fecha de actualización del servidor analizado
# + TCP_CONVERSATION_EXCHANGE: Esta variable es el número de paquetes TCP intercambiados entre el servidor y nuestro cliente honeypot
# + DIST_REMOTE_TCP_PORT: es el número de puertos detectados y diferentes a TCP
# + REMOTE_IPS: esta variable tiene el número total de IPs conectadas al honeypot
# + APP_BYTES: es el número de bytes transferidos
# + SOURCE_APP_PACKETS: paquetes enviados desde el honeypot al servidor
# + REMOTE_APP_PACKETS: paquetes recibidos del servidor
# + APP_PACKETS: número total de paquetes IP generados durante la comunicación entre el honeypot y el servidor.
# + DNS_QUERY_TIMES: número de paquetes DNS generados durante la comunicación entre el honeypot y el servidor.
# + TYPE: es una variable categórica, sus valores representan el tipo de página web analizada, en concreto, 1 es para sitios web maliciosos y 0 para sitios web benignos
#
# # Desafío 1 - Explorar el conjunto de datos
#
# Empecemos explorando el conjunto de datos. Primero carga el archivo de datos:

# %%
websites = pd.read_csv('../website.csv')

# %% [markdown]
# #### Explore los datos a vista de pájaro.
#
# Ahora ya deberías estar muy familiarizado con los procedimientos, así que no te daremos las instrucciones paso a paso. Reflexiona sobre lo que hiciste en los laboratorios anteriores y explora el conjunto de datos.
#
# Cosas que buscarás:
#
# * ¿Qué aspecto tiene el conjunto de datos?
# * ¿Cuáles son los tipos de datos?
# * ¿Qué columnas contienen las características de los sitios web?
# * ¿Qué columna contiene la característica que vamos a predecir? ¿Cuál es el código de los sitios web benignos frente a los maliciosos?
# * ¿Necesitamos transformar alguna de las columnas de categórica a ordinal? En caso afirmativo, ¿cuáles son esas columnas?
#
# Siéntete libre de añadir celdas adicionales para tus exploraciones. Asegúrate de comentar lo que descubras.

# %%
websites.head()
# Out:
#        URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0   M0_109          16                          7  iso-8859-1
# 1  B0_2314          16                          6       UTF-8
# 2   B0_911          16                          6    us-ascii
# 3   B0_113          17                          6  ISO-8859-1
# 4   B0_403          17                          6       UTF-8
#
#                   SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                  nginx           263.0           NaN            NaN
# 1          Apache/2.4.10         15087.0           NaN            NaN
# 2  Microsoft-HTTPAPI/2.0           324.0           NaN            NaN
# 3                  nginx           162.0            US             AK
# 4                    NaN        124140.0            US             TX
#
#       WHOIS_REGDATE WHOIS_UPDATED_DATE  ...  DIST_REMOTE_TCP_PORT  REMOTE_IPS  \
# 0  10/10/2015 18:21                NaN  ...                     0           2
# 1               NaN                NaN  ...                     7           4
# 2               NaN                NaN  ...                     0           0
# 3    7/10/1997 4:00    12/09/2013 0:45  ...                    22           3
# 4   12/05/1996 0:00    11/04/2017 0:00  ...                     2           5
#
#    APP_BYTES  SOURCE_APP_PACKETS  REMOTE_APP_PACKETS  SOURCE_APP_BYTES  \
# 0        700                   9                  10              1153
# 1       1230                  17                  19              1265
# 2          0                   0                   0                 0
# 3       3812                  39                  37             18784
# 4       4278                  61                  62            129889
#
#    REMOTE_APP_BYTES  APP_PACKETS  DNS_QUERY_TIMES  Type
# 0               832            9              2.0     1
# 1              1230           17              0.0     0
# 2                 0            0              0.0     0
# 3              4380           39              8.0     0
# 4              4586           61              4.0     0
#
# [5 rows x 21 columns]

# %%
websites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   URL                        1781 non-null   object
#  1   URL_LENGTH                 1781 non-null   int64
#  2   NUMBER_SPECIAL_CHARACTERS  1781 non-null   int64
#  3   CHARSET                    1774 non-null   object
#  4   SERVER                     1605 non-null   object
#  5   CONTENT_LENGTH             969 non-null    float64
#  6   WHOIS_COUNTRY              1475 non-null   object
#  7   WHOIS_STATEPRO             1419 non-null   object
#  8   WHOIS_REGDATE              1654 non-null   object
#  9   WHOIS_UPDATED_DATE         1642 non-null   object
#  10  TCP_CONVERSATION_EXCHANGE  1781 non-null   int64
#  11  DIST_REMOTE_TCP_PORT       1781 non-null   int64
#  12  REMOTE_IPS                 1781 non-null   int64
#  13  APP_BYTES                  1781 non-null   int64
#  14  SOURCE_APP_PACKETS         1781 non-null   int64
#  15  REMOTE_APP_PACKETS         1781 non-null   int64
#  16  SOURCE_APP_BYTES           1781 non-null   int64
#  17  REMOTE_APP_BYTES           1781 non-null   int64
#  18  APP_PACKETS                1781 non-null   int64
#  19  DNS_QUERY_TIMES            1780 non-null   float64
#  20  Type                       1781 non-null   int64
# dtypes: float64(2), int64(12), object(7)
# memory usage: 292.3+ KB

# %%
websites.describe()
# Out:
#         URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  CONTENT_LENGTH  \
# count  1781.000000                1781.000000      969.000000
# mean     56.961258                  11.111735    11726.927761
# std      27.555586                   4.549896    36391.809051
# min      16.000000                   5.000000        0.000000
# 25%      39.000000                   8.000000      324.000000
# 50%      49.000000                  10.000000     1853.000000
# 75%      68.000000                  13.000000    11323.000000
# max     249.000000                  43.000000   649263.000000
#
#        TCP_CONVERSATION_EXCHANGE  DIST_REMOTE_TCP_PORT   REMOTE_IPS  \
# count                1781.000000           1781.000000  1781.000000
# mean                   16.261089              5.472768     3.060640
# std                    40.500975             21.807327     3.386975
# min                     0.000000              0.000000     0.000000
# 25%                     0.000000              0.000000     0.000000
# 50%                     7.000000              0.000000     2.000000
# 75%                    22.000000              5.000000     5.000000
# max                  1194.000000            708.000000    17.000000
#
#           APP_BYTES  SOURCE_APP_PACKETS  REMOTE_APP_PACKETS  SOURCE_APP_BYTES  \
# count  1.781000e+03         1781.000000         1781.000000      1.781000e+03
# mean   2.982339e+03           18.540146           18.746210      1.589255e+04
# std    5.605057e+04           41.627173           46.397969      6.986193e+04
# min    0.000000e+00            0.000000            0.000000      0.000000e+00
# 25%    0.000000e+00            0.000000            0.000000      0.000000e+00
# 50%    6.720000e+02            8.000000            9.000000      5.790000e+02
# 75%    2.328000e+03           26.000000           25.000000      9.806000e+03
# max    2.362906e+06         1198.000000         1284.000000      2.060012e+06
#
#        REMOTE_APP_BYTES  APP_PACKETS  DNS_QUERY_TIMES         Type
# count      1.781000e+03  1781.000000      1780.000000  1781.000000
# mean       3.155599e+03    18.540146         2.263483     0.121280
# std        5.605378e+04    41.627173         2.930853     0.326544
# min        0.000000e+00     0.000000         0.000000     0.000000
# 25%        0.000000e+00     0.000000         0.000000     0.000000
# 50%        7.350000e+02     8.000000         0.000000     0.000000
# 75%        2.701000e+03    26.000000         4.000000     0.000000
# max        2.362906e+06  1198.000000        20.000000     1.000000

# %%
variables = websites.iloc[:,0:20]

#X = variables

# %%
resultado = websites.iloc[:,20:21]
#y = resultado

# The code of out predict variable of benign vs malicious websites is 0 for bening and 1 for maliciuos websites

# %% [markdown]
# #### A continuación, evalúe si las columnas de este conjunto de datos están fuertemente correlacionadas.
#
# En el laboratorio de aprendizaje supervisado Mushroom que hicimos recientemente, mencionamos que nos preocupa si nuestro conjunto de datos tiene columnas fuertemente correlacionadas porque si es el caso tenemos que elegir ciertos algoritmos de ML en lugar de otros. Ahora tenemos que evaluar esto para nuestro conjunto de datos.
#
# Por suerte, la mayoría de las columnas de este conjunto de datos son ordinales, lo que nos facilita mucho las cosas. En las siguientes celdas, evalúe el nivel de colinealidad de los datos.
#
# Aquí tienes algunas indicaciones generales que puede consultar para completar este paso:
#
# 1. Crea una matriz de correlaciones utilizando las columnas numéricas del conjunto de datos.
#
# 2. Crea un mapa de calor utilizando `seaborn` para visualizar qué columnas tienen una alta colinealidad.
#
# 3. Comenta qué columnas podría necesitar eliminar debido a la alta colinealidad.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Seleccionar solo las columnas numéricas del DataFrame
columnas_numericas = websites.select_dtypes(include=['number'])

# Calcular la matriz de correlaciones
matriz_correlaciones = columnas_numericas.corr()

# Crear un mapa de calor de la matriz de correlaciones
plt.figure(figsize=(10, 8))  # Ajusta el tamaño del gráfico según el número de columnas
sns.heatmap(
    matriz_correlaciones,
    annot=True,            # Añadir los valores de correlación en cada celda
    fmt='.2f',            # Formato de los valores numéricos
    cmap='coolwarm',      # Paleta de colores
    linewidths=0.5,       # Ancho de las líneas que separan las celdas
    vmin=-1,              # Valor mínimo de la escala de colores
    vmax=1                # Valor máximo de la escala de colores
)
plt.title('Matriz de Correlaciones')
plt.show()

# %%
UMBRAL = 0.9 

# Encontrar pares de columnas con alta correlación
def encontrar_colinealidad_alta(matriz_correlaciones, umbral):
    alta_colinealidad = []
    num_columnas = matriz_correlaciones.shape[0]
    
    for i in range(num_columnas):
        for j in range(i + 1, num_columnas):
            if abs(matriz_correlaciones.iloc[i, j]) > umbral:
                columna_i = matriz_correlaciones.columns[i]
                columna_j = matriz_correlaciones.columns[j]
                alta_colinealidad.append((columna_i, columna_j, matriz_correlaciones.iloc[i, j]))
    
    return alta_colinealidad

# Llamar a la función para encontrar pares con alta colinealidad
colinealidad_alta = encontrar_colinealidad_alta(matriz_correlaciones, UMBRAL)

# Mostrar los resultados
if colinealidad_alta:
    print("Pares de columnas con alta colinealidad:")
    for columna_i, columna_j, correlacion in colinealidad_alta:
        print(f"Columnas: '{columna_i}' y '{columna_j}' - Correlación: {correlacion:.2f}")
else:
    print("No se encontraron pares de columnas con alta colinealidad.")
# Out:
# Pares de columnas con alta colinealidad:
# Columnas: 'URL_LENGTH' y 'NUMBER_SPECIAL_CHARACTERS' - Correlación: 0.92
# Columnas: 'TCP_CONVERSATION_EXCHANGE' y 'SOURCE_APP_PACKETS' - Correlación: 1.00
# Columnas: 'TCP_CONVERSATION_EXCHANGE' y 'REMOTE_APP_PACKETS' - Correlación: 0.99
# Columnas: 'TCP_CONVERSATION_EXCHANGE' y 'APP_PACKETS' - Correlación: 1.00
# Columnas: 'APP_BYTES' y 'REMOTE_APP_BYTES' - Correlación: 1.00
# Columnas: 'SOURCE_APP_PACKETS' y 'REMOTE_APP_PACKETS' - Correlación: 0.99
# Columnas: 'SOURCE_APP_PACKETS' y 'APP_PACKETS' - Correlación: 1.00
# Columnas: 'REMOTE_APP_PACKETS' y 'APP_PACKETS' - Correlación: 0.99

# %% [markdown]
# ### Este es un ejemplo para conocer la importancia de las características usando un modelo ML

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X = websites._get_numeric_data().drop('Type', axis=1)
y = websites.Type

# %%
model = XGBClassifier()

model.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
sort_idx = model.feature_importances_.argsort()

# %%
plt.barh(X.columns[sort_idx],model.feature_importances_[sort_idx])
plt.show();

# %% [markdown]
#     En el gráfico anterior podemos ver las características con menor peso en el conjunto de datos.

# %% [markdown]
# # Desafío 2 - Eliminar la colinealidad de columnas.
#
# En el mapa de calor que ha creado, deberías haber visto al menos 3 columnas que pueden eliminarse debido a la alta colinealidad. Elimina estas columnas del conjunto de datos.
#
# Ten en cuenta que debes eliminar el menor número posible de columnas. No tienes que eliminar todas las columnas a la vez. En su lugar, intenta eliminar una columna y, a continuación, vuelve a elaborar el mapa térmico para determinar si deben eliminarse columnas adicionales. Cuando el conjunto de datos ya no contenga columnas correlacionadas en más de un 90%, puedes parar. Además, ten en cuenta que cuando dos columnas tienen una alta colinealidad, sólo necesitas eliminar una de ellas, pero no ambas.
#
# En las celdas de abajo, elimina tantas columnas como puedas para eliminar la alta colinealidad en el conjunto de datos. Asegúrate de comentar tu camino para que se pueda conocer tu razonamiento, lo que permitirá dar feedback. Al final, vuelve a imprimir el mapa de calor.

# %%
# Eliminar 'TCP_CONVERSATION_EXCHANGE' y recalcular la matriz de correlaciones
websites_reducido = websites.drop(columns=['TCP_CONVERSATION_EXCHANGE'])

# Recalcular la matriz de correlaciones
columnas_numericas_reducido = websites_reducido.select_dtypes(include=['number'])
matriz_correlaciones_reducida = columnas_numericas_reducido.corr()

# Crear un nuevo mapa de calor
plt.figure(figsize=(12, 10))
sns.heatmap(matriz_correlaciones_reducida, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlaciones - Después de eliminar TCP_CONVERSATION_EXCHANGE')
plt.show()

# %%
# Eliminar 'SOURCE_APP_PACKETS' y recalcular la matriz de correlaciones
websites_reducido = websites_reducido.drop(columns=['SOURCE_APP_PACKETS'])

# Recalcular la matriz de correlaciones
columnas_numericas_reducido = websites_reducido.select_dtypes(include=['number'])
matriz_correlaciones_reducida = columnas_numericas_reducido.corr()

# Crear un nuevo mapa de calor
plt.figure(figsize=(12, 10))
sns.heatmap(matriz_correlaciones_reducida, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlaciones - Después de eliminar SOURCE_APP_PACKETS')
plt.show()

# %%
# Eliminar 'APP_PACKETS' y recalcular la matriz de correlaciones
websites_reducido = websites_reducido.drop(columns=['APP_PACKETS'])

# Recalcular la matriz de correlaciones
columnas_numericas_reducido = websites_reducido.select_dtypes(include=['number'])
matriz_correlaciones_reducida = columnas_numericas_reducido.corr()

# Crear un nuevo mapa de calor
plt.figure(figsize=(12, 10))
sns.heatmap(matriz_correlaciones_reducida, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlaciones - Después de eliminar APP_PACKETS')
plt.show()

# %%
# REMOVE THE 4 COLUMNS WITH MORE COLLINEARITY

# %%
def eliminar_colinealidad(websites, num_columnas_a_eliminar=4, umbral=0.9):
    columnas_a_eliminar = []
    columnas_numericas = websites.select_dtypes(include=['number'])
    matriz_correlaciones = columnas_numericas.corr()
    
    for _ in range(num_columnas_a_eliminar):
        # Encontrar pares de columnas con alta colinealidad
        alta_colinealidad = encontrar_colinealidad_alta(matriz_correlaciones, umbral)
        if not alta_colinealidad:
            break
        
        # Ordenar los pares por la magnitud de la correlación (de mayor a menor)
        alta_colinealidad.sort(key=lambda x: abs(x[2]), reverse=True)
        
        # Eliminar la columna que aparece primero en la lista de alta colinealidad
        columna_a_eliminar = alta_colinealidad[0][0]
        columnas_a_eliminar.append(columna_a_eliminar)
        websites = websites.drop(columns=[columna_a_eliminar])
        
        # Recalcular la matriz de correlaciones
        columnas_numericas = websites.select_dtypes(include=['number'])
        matriz_correlaciones = columnas_numericas.corr()
    
    return websites, columnas_a_eliminar

# Función para encontrar pares de columnas con alta colinealidad
def encontrar_colinealidad_alta(matriz_correlaciones, umbral):
    alta_colinealidad = []
    num_columnas = matriz_correlaciones.shape[0]
    
    for i in range(num_columnas):
        for j in range(i + 1, num_columnas):
            if abs(matriz_correlaciones.iloc[i, j]) > umbral:
                columna_i = matriz_correlaciones.columns[i]
                columna_j = matriz_correlaciones.columns[j]
                alta_colinealidad.append((columna_i, columna_j, matriz_correlaciones.iloc[i, j]))
    
    return alta_colinealidad

# Eliminar 4 columnas con alta colinealidad
websites_reducido, columnas_eliminadas = eliminar_colinealidad(websites, num_columnas_a_eliminar=4)

# Imprimir columnas eliminadas
print(f"Columnas eliminadas: {columnas_eliminadas}")

# Crear el mapa de calor final
columnas_numericas_reducido = websites_reducido.select_dtypes(include=['number'])
matriz_correlaciones_reducida = columnas_numericas_reducido.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(matriz_correlaciones_reducida, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlaciones - Final')
plt.show()
# Out:
# Columnas eliminadas: ['SOURCE_APP_PACKETS', 'APP_BYTES', 'TCP_CONVERSATION_EXCHANGE', 'REMOTE_APP_PACKETS']

# %% [markdown]
# # Reto 3 - Manejar los valores que faltan
#
# El siguiente paso sería manejar los valores faltantes. **Comenzamos examinando el número de valores que faltan en cada columna.**

# %%
websites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   URL                        1781 non-null   object
#  1   URL_LENGTH                 1781 non-null   int64
#  2   NUMBER_SPECIAL_CHARACTERS  1781 non-null   int64
#  3   CHARSET                    1774 non-null   object
#  4   SERVER                     1605 non-null   object
#  5   CONTENT_LENGTH             969 non-null    float64
#  6   WHOIS_COUNTRY              1475 non-null   object
#  7   WHOIS_STATEPRO             1419 non-null   object
#  8   WHOIS_REGDATE              1654 non-null   object
#  9   WHOIS_UPDATED_DATE         1642 non-null   object
#  10  TCP_CONVERSATION_EXCHANGE  1781 non-null   int64
#  11  DIST_REMOTE_TCP_PORT       1781 non-null   int64
#  12  REMOTE_IPS                 1781 non-null   int64
#  13  APP_BYTES                  1781 non-null   int64
#  14  SOURCE_APP_PACKETS         1781 non-null   int64
#  15  REMOTE_APP_PACKETS         1781 non-null   int64
#  16  SOURCE_APP_BYTES           1781 non-null   int64
#  17  REMOTE_APP_BYTES           1781 non-null   int64
#  18  APP_PACKETS                1781 non-null   int64
#  19  DNS_QUERY_TIMES            1780 non-null   float64
#  20  Type                       1781 non-null   int64
# dtypes: float64(2), int64(12), object(7)
# memory usage: 292.3+ KB

# %%
valores_faltantes = websites.isnull().sum() / len(websites)
print(valores_faltantes[valores_faltantes > 0])
# Out:
# CHARSET               0.003930
# SERVER                0.098821
# CONTENT_LENGTH        0.455924
# WHOIS_COUNTRY         0.171814
# WHOIS_STATEPRO        0.203257
# WHOIS_REGDATE         0.071308
# WHOIS_UPDATED_DATE    0.078046
# DNS_QUERY_TIMES       0.000561
# dtype: float64

# %%
websites_sin_faltantes = websites.dropna()

print(websites_sin_faltantes.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 636 entries, 3 to 1780
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   URL                        636 non-null    object
#  1   URL_LENGTH                 636 non-null    int64
#  2   NUMBER_SPECIAL_CHARACTERS  636 non-null    int64
#  3   CHARSET                    636 non-null    object
#  4   SERVER                     636 non-null    object
#  5   CONTENT_LENGTH             636 non-null    float64
#  6   WHOIS_COUNTRY              636 non-null    object
#  7   WHOIS_STATEPRO             636 non-null    object
#  8   WHOIS_REGDATE              636 non-null    object
#  9   WHOIS_UPDATED_DATE         636 non-null    object
#  10  TCP_CONVERSATION_EXCHANGE  636 non-null    int64
#  11  DIST_REMOTE_TCP_PORT       636 non-null    int64
#  12  REMOTE_IPS                 636 non-null    int64
#  13  APP_BYTES                  636 non-null    int64
#  14  SOURCE_APP_PACKETS         636 non-null    int64
#  15  REMOTE_APP_PACKETS         636 non-null    int64
#  16  SOURCE_APP_BYTES           636 non-null    int64
#  17  REMOTE_APP_BYTES           636 non-null    int64
#  18  APP_PACKETS                636 non-null    int64
#  19  DNS_QUERY_TIMES            636 non-null    float64
#  20  Type                       636 non-null    int64
# dtypes: float64(2), int64(12), object(7)
# memory usage: 109.3+ KB
# None

# %% [markdown]
# # Reto 4 - Manejar datos categóricos `WHOIS_*

# %% [markdown]
# Hay varias columnas categóricas que necesitamos manejar. Estas columnas son:
#
# * URL
# * CHARSET
# * SERVIDOR
# * PAÍS
# * «WHOIS_STATEPRO
# * WHOIS_REGDATE
# * WHOIS_UPDATED_DATE
#
# La forma de tratar las columnas de cadena es siempre caso por caso. Empecemos trabajando con `WHOIS_COUNTRY`. Tus pasos son:
#
# 1. Enumera los valores únicos de `WHOIS_COUNTRY`.
# 1. Consolide los valores de país con códigos de país coherentes. Por ejemplo, los siguientes valores se refieren al mismo país y deben utilizar un código de país coherente:
#     * `CY` y `Cyprus`.
#     * US y US
#     * SE y SE
#     * GB, Reino Unido y GB, Reino Unido.
#
# #### En las celdas de abajo, fija los valores de los países como se indica arriba.

# %%
websites.WHOIS_COUNTRY.value_counts()
# Out:
# WHOIS_COUNTRY
# US                1103
# CA                  84
# ES                  63
# AU                  35
# PA                  21
# GB                  19
# JP                  11
# UK                  10
# IN                  10
# CN                  10
# CZ                   9
# FR                   9
# NL                   6
# CH                   6
# KR                   5
# [u'GB'; u'UK']       5
# ru                   4
# BS                   4
# AT                   4
# PH                   4
# us                   3
# SC                   3
# DE                   3
# BE                   3
# HK                   3
# TR                   3
# SE                   3
# KY                   3
# RU                   2
# NO                   2
# SI                   2
# IL                   2
# KG                   2
# BR                   2
# UA                   2
# Cyprus               2
# UY                   2
# se                   1
# LU                   1
# TH                   1
# UG                   1
# LV                   1
# United Kingdom       1
# PK                   1
# BY                   1
# IT                   1
# IE                   1
# AE                   1
# Name: count, dtype: int64

# %%
good_country = {'None':'None', 
                'US':'US', 
                'SC':'SC', 
                'GB':'UK', 
                'UK':'UK', 
                'RU':'RU', 
                'AU':'AU', 
                'CA':'CA',
                'PA':'PA',
                'se':'SE', 
                'IN':'IN',
                'LU':'LU', 
                'TH':'TH', 
                "[u'GB'; u'UK']":'UK', 
                'FR':'FR',
                'NL':'NL',
                'UG':'UG', 
                'JP':'JP', 
                'CN':'CN', 
                'SE':'SE',
                'SI':'SI', 
                'IL':'IL', 
                'ru':'RU', 
                'KY':'KY', 
                'AT':'AT', 
                'CZ':'CZ', 
                'PH':'PH', 
                'BE':'BE', 
                'NO':'NO', 
                'TR':'TR', 
                'LV':'LV',
                'DE':'DE', 
                'ES':'ES', 
                'BR':'BR', 
                'us':'US', 
                'KR':'KR', 
                'HK':'HK', 
                'UA':'UA', 
                'CH':'CH', 
                'United Kingdom':'UK',
                'BS':'BS', 
                'PK':'PK', 
                'IT':'IT', 
                'Cyprus':'CY', 
                'BY':'BY', 
                'AE':'AE', 
                'IE':'IE', 
                'UY':'UY', 
                'KG':'KG'}

# %%
import pandas as pd

# Supongamos que 'websites' es el DataFrame que estamos utilizando.

# Definir el diccionario de mapeo
good_country = {'None': 'None', 
                'US': 'US', 
                'SC': 'SC', 
                'GB': 'UK', 
                'UK': 'UK', 
                'RU': 'RU', 
                'AU': 'AU', 
                'CA': 'CA',
                'PA': 'PA',
                'se': 'SE', 
                'IN': 'IN',
                'LU': 'LU', 
                'TH': 'TH', 
                "[u'GB'; u'UK']": 'UK', 
                'FR': 'FR',
                'NL': 'NL',
                'UG': 'UG', 
                'JP': 'JP', 
                'CN': 'CN', 
                'SE': 'SE',
                'SI': 'SI', 
                'IL': 'IL', 
                'ru': 'RU', 
                'KY': 'KY', 
                'AT': 'AT', 
                'CZ': 'CZ', 
                'PH': 'PH', 
                'BE': 'BE', 
                'NO': 'NO', 
                'TR': 'TR', 
                'LV': 'LV',
                'DE': 'DE', 
                'ES': 'ES', 
                'BR': 'BR', 
                'us': 'US', 
                'KR': 'KR', 
                'HK': 'HK', 
                'UA': 'UA', 
                'CH': 'CH', 
                'United Kingdom': 'UK',
                'BS': 'BS', 
                'PK': 'PK', 
                'IT': 'IT', 
                'Cyprus': 'CY', 
                'BY': 'BY', 
                'AE': 'AE', 
                'IE': 'IE', 
                'UY': 'UY', 
                'KG': 'KG'}


websites['WHOIS_COUNTRY'].fillna('Desconocido', inplace=True)


websites['WHOIS_COUNTRY'] = websites['WHOIS_COUNTRY'].apply(lambda x: good_country.get(x, 'Desconocido'))
# Out:
# /tmp/ipykernel_6791/2615193462.py:57: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   websites['WHOIS_COUNTRY'].fillna('Desconocido', inplace=True)

# %%
websites.WHOIS_COUNTRY.unique()
# Out:
# array(['Desconocido', 'US', 'SC', 'UK', 'RU', 'AU', 'CA', 'PA', 'SE',
#        'IN', 'LU', 'TH', 'FR', 'NL', 'UG', 'JP', 'CN', 'SI', 'IL', 'KY',
#        'AT', 'CZ', 'PH', 'BE', 'NO', 'TR', 'LV', 'DE', 'ES', 'BR', 'KR',
#        'HK', 'UA', 'CH', 'BS', 'PK', 'IT', 'BY', 'AE', 'IE', 'UY', 'KG'],
#       dtype=object)

# %% [markdown]
# Ya que hemos fijado los valores de los países, ¿podemos convertir ahora esta columna en ordinal?
#
# Todavía no. Si reflexionas, en los laboratorios anteriores sobre cómo manejamos las columnas categóricas, probablemente recuerdes que acabamos eliminando muchas de esas columnas porque hay demasiados valores únicos. Demasiados valores únicos en una columna no es deseable en el aprendizaje automático porque hace que la predicción sea inexacta. Pero hay soluciones bajo ciertas condiciones. Una de las condiciones solucionables es:
#
# #### Si un número limitado de valores representa la mayoría de los datos, podemos conservar estos valores principales y volver a etiquetar todos los demás valores poco frecuentes.
#
# La columna `WHOIS_COUNTRY` resulta ser este caso. Puedes comprobarlo imprimiendo un gráfico de barras de los `value_counts` en la siguiente celda para verificarlo:

# %%
# Your code here
def print_bar_plot(x,y):
    plt.bar(x, y)
    plt.figure(figsize=(50,10))
    return plt.show()

# %%
def print_bar_plot(x, y):
    plt.figure(figsize=(25, 10))  # Ajusta el tamaño de la figura para ocupar todo el ancho de la hoja
    plt.bar(x, y, color='skyblue')
    plt.xticks(rotation=90, ha='right')
    plt.tight_layout()
    plt.show()

# %%
print_bar_plot(websites.WHOIS_COUNTRY.unique(),websites.WHOIS_COUNTRY.value_counts());

# %% [markdown]
# #### Después de verificar, ahora vamos a mantener los 10 primeros valores de la columna y volver a etiquetar otras columnas con `OTHER`.

# %%
top_10_values = websites['WHOIS_COUNTRY'].value_counts().head(10).index

# Reemplazar los valores menos frecuentes con 'OTHER'
websites['WHOIS_COUNTRY'] = websites['WHOIS_COUNTRY'].apply(lambda x: x if x in top_10_values else 'OTHER')

# Verificar los cambios
print("Frecuencias después de agrupar los valores poco frecuentes:")
print(websites['WHOIS_COUNTRY'].value_counts())

# Opcional: Imprimir gráfico de barras para verificar visualmente
def print_bar_plot(x, y):
    plt.figure(figsize=(30, 10))  # Ajusta el tamaño de la figura para ocupar todo el ancho de la hoja
    plt.bar(x, y, color='skyblue')
    plt.title('Distribución de Valores en WHOIS_COUNTRY')
    plt.xlabel('País')
    plt.ylabel('Número de Ocurrencias')
    plt.xticks(rotation=90, ha='right')  # Rotar etiquetas del eje x para mayor legibilidad
    plt.tight_layout()  # Ajusta el diseño para evitar el recorte de etiquetas
    plt.show()

# Obtener los valores únicos y sus frecuencias después del reemplazo
valores_actualizados = websites['WHOIS_COUNTRY'].value_counts().index
frecuencias_actualizadas = websites['WHOIS_COUNTRY'].value_counts().values

# Llamar a la función para imprimir el gráfico de barras
print_bar_plot(valores_actualizados, frecuencias_actualizadas)
# Out:
# Frecuencias después de agrupar los valores poco frecuentes:
# WHOIS_COUNTRY
# US             1106
# Desconocido     308
# OTHER            98
# CA               84
# ES               63
# AU               35
# UK               35
# PA               21
# JP               11
# IN               10
# CN               10
# Name: count, dtype: int64

# %%
print(top_10_values)
# Out:
# Index(['US', 'Desconocido', 'CA', 'ES', 'AU', 'UK', 'PA', 'JP', 'IN', 'CN'], dtype='object', name='WHOIS_COUNTRY')

# %% [markdown]
# Ahora que se ha cambiado la etiqueta `WHOIS_COUNTRY`, ya no necesitamos `WHOIS_STATEPRO` porque los valores de los estados o provincias pueden dejar de ser relevantes. Eliminaremos esta columna.
#
# Además, también eliminaremos `WHOIS_REGDATE` y `WHOIS_UPDATED_DATE`. Se trata de las fechas de registro y actualización de los dominios del sitio web. No son de nuestra incumbencia.
#
# #### En la siguiente celda, elimina `['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']`.

# %%
print("Columnas actuales en el DataFrame:")
print(websites.columns)

# Especificar las columnas a eliminar
eliminar = ['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']

# Eliminar las columnas, ignorando si algunas de ellas no existen
websites = websites.drop(columns=eliminar, errors='ignore')


print("Columnas restantes en el DataFrame después de eliminar:")
print(websites.columns)
# Out:
# Columnas actuales en el DataFrame:
# Index(['URL', 'URL_LENGTH', 'NUMBER_SPECIAL_CHARACTERS', 'CHARSET', 'SERVER',
#        'CONTENT_LENGTH', 'WHOIS_COUNTRY', 'TCP_CONVERSATION_EXCHANGE',
#        'DIST_REMOTE_TCP_PORT', 'REMOTE_IPS', 'APP_BYTES', 'SOURCE_APP_PACKETS',
#        'REMOTE_APP_PACKETS', 'SOURCE_APP_BYTES', 'REMOTE_APP_BYTES',
#        'APP_PACKETS', 'DNS_QUERY_TIMES', 'Type'],
#       dtype='object')
# Columnas restantes en el DataFrame después de eliminar:
# Index(['URL', 'URL_LENGTH', 'NUMBER_SPECIAL_CHARACTERS', 'CHARSET', 'SERVER',
#        'CONTENT_LENGTH', 'WHOIS_COUNTRY', 'TCP_CONVERSATION_EXCHANGE',
#        'DIST_REMOTE_TCP_PORT', 'REMOTE_IPS', 'APP_BYTES', 'SOURCE_APP_PACKETS',
#        'REMOTE_APP_PACKETS', 'SOURCE_APP_BYTES', 'REMOTE_APP_BYTES',
#        'APP_PACKETS', 'DNS_QUERY_TIMES', 'Type'],
#       dtype='object')

# %% [markdown]
# # Reto 5 - Manejar los datos categóricos restantes y convertirlos en ordinales
#
# Ahora vuelve a imprimir los `dtypes` de los datos. Además de `WHOIS_COUNTRY` que ya hemos arreglado, deberían quedar 3 columnas categóricas: `URL`, `CHARSET`, y `SERVER`.

# %%
print(websites.dtypes)
# Out:
# URL                           object
# URL_LENGTH                     int64
# NUMBER_SPECIAL_CHARACTERS      int64
# CHARSET                       object
# SERVER                        object
# CONTENT_LENGTH               float64
# WHOIS_COUNTRY                 object
# TCP_CONVERSATION_EXCHANGE      int64
# DIST_REMOTE_TCP_PORT           int64
# REMOTE_IPS                     int64
# APP_BYTES                      int64
# SOURCE_APP_PACKETS             int64
# REMOTE_APP_PACKETS             int64
# SOURCE_APP_BYTES               int64
# REMOTE_APP_BYTES               int64
# APP_PACKETS                    int64
# DNS_QUERY_TIMES              float64
# Type                           int64
# dtype: object

# %% [markdown]
# #### `URL` es fácil. Simplemente lo eliminaremos porque tiene demasiados valores únicos que no hay forma de consolidar.

# %%
websites = websites.drop(columns=['URL'])
print(websites.columns)
# Out:
# Index(['URL_LENGTH', 'NUMBER_SPECIAL_CHARACTERS', 'CHARSET', 'SERVER',
#        'CONTENT_LENGTH', 'WHOIS_COUNTRY', 'TCP_CONVERSATION_EXCHANGE',
#        'DIST_REMOTE_TCP_PORT', 'REMOTE_IPS', 'APP_BYTES', 'SOURCE_APP_PACKETS',
#        'REMOTE_APP_PACKETS', 'SOURCE_APP_BYTES', 'REMOTE_APP_BYTES',
#        'APP_PACKETS', 'DNS_QUERY_TIMES', 'Type'],
#       dtype='object')

# %% [markdown]
# #### Imprime el recuento de valores únicos de `CHARSET`. Usted ve que hay sólo unos pocos valores únicos. Así que podemos dejarlo como está.

# %%
charset_value_counts = websites['CHARSET'].value_counts()
print(charset_value_counts)
# Out:
# CHARSET
# UTF-8           676
# ISO-8859-1      427
# utf-8           379
# us-ascii        155
# iso-8859-1      134
# windows-1251      1
# ISO-8859          1
# windows-1252      1
# Name: count, dtype: int64

# %%
valores_server = websites.SERVER.value_counts()
print(valores_server)
# Out:
# SERVER
# Apache                                                                             386
# nginx                                                                              211
# Microsoft-HTTPAPI/2.0                                                              113
# cloudflare-nginx                                                                    94
# Microsoft-IIS/7.5                                                                   51
#                                                                                   ...
# Apache/2.2.31 (Unix) mod_ssl/2.2.31 OpenSSL/0.9.8e-fips-rhel5 mod_bwlimited/1.4      1
# Apache/2.4.18 (Unix) OpenSSL/1.0.2e Communique/4.1.10                                1
# mw2241.codfw.wmnet                                                                   1
# Apache/1.3.33 (Unix) mod_ssl/2.8.24 OpenSSL/0.9.7e-p1 PHP/4.4.8                      1
# fbs                                                                                  1
# Name: count, Length: 238, dtype: int64

# %% [markdown]
# `SERVER` es un poco más complicado. Imprime sus valores únicos y piensa cómo puedes consolidar esos valores.
#
# #### Antes de pensar en tu propia solución, no leas las instrucciones que vienen a continuación.

# %%
def reetiquetar_servidor(valor):
    if pd.isna(valor):  #por si el valor es NaN
        return 'Other'
    valor = valor.lower()  # minusculas
    if 'microsoft' in valor:
        return 'Microsoft'
    elif 'apache' in valor:
        return 'Apache'
    elif 'nginx' in valor:
        return 'Nginx'
    elif 'cloudflare' in valor:
        return 'Cloudflare'
    else:
        return 'Other'

websites['SERVER'] = websites['SERVER'].astype(str).apply(reetiquetar_servidor)

# %% [markdown]
# Aunque hay tantos valores únicos en la columna `SERVER`, en realidad sólo hay 3 tipos principales de servidores: Microsoft, Apache y Nginx. Simplemente comprueba si cada valor de `SERVER` contiene alguno de esos tipos de servidor y vuelve a etiquetarlos. Para los valores `SERVER` que no contengan ninguna de esas subcadenas, etiquétalos con `Other`.
#
# Al final, la columna «SERVIDOR» sólo debe contener 4 valores únicos: `Microsoft`, `Apache`, `nginx`, y `Other`.

# %%
print(websites['SERVER'].value_counts())
# Out:
# SERVER
# Apache       643
# Other        504
# Nginx        436
# Microsoft    198
# Name: count, dtype: int64

# %% [markdown]
# OK, todos nuestros datos categóricos están fijados ahora. **Vamos a convertirlos en datos ordinales usando la función `get_dummies` de Pandas ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)). Asegúrate de eliminar las columnas categóricas pasando `drop_first=True` a `get_dummies` ya que no las necesitamos. **Además, asigna los datos con valores ficticios a una nueva variable `website_dummy`.

# %%
from sklearn.preprocessing import LabelEncoder

# Crear una copia del DataFrame para almacenar los resultados
website_dummy = websites.copy()

# Definir las columnas categóricas
columnas_categoricas = ['CHARSET', 'SERVER', 'WHOIS_COUNTRY']

# Inicializar el LabelEncoder
le = LabelEncoder()

# Crear un diccionario para almacenar el mapeo de cada columna categórica
mapeo_categorias = {}

# Convertir cada columna categórica en números y guardar el mapeo
for col in columnas_categoricas:
    website_dummy[col] = le.fit_transform(website_dummy[col]) + 1  # Agregar 1 para comenzar desde 1
    # Guardar el mapeo en el diccionario
    mapeo_categorias[col] = dict(zip(le.classes_, le.transform(le.classes_) + 1))

# Verificar el resultado
print("Primeras filas de website_dummy:")
print(website_dummy.head())

# Verificar el diccionario de mapeo
print("\nDiccionario de mapeo:")
print(mapeo_categorias)

# Verificar los tipos de datos de cada columna
print("\nTipos de datos de cada columna en website_dummy:")
print(website_dummy.dtypes)
# Out:
# Primeras filas de website_dummy:
#    URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  CHARSET  SERVER  CONTENT_LENGTH  \
# 0          16                          7        4       3           263.0
# 1          16                          6        3       1         15087.0
# 2          16                          6        5       2           324.0
# 3          17                          6        2       3           162.0
# 4          17                          6        3       4        124140.0
#
#    WHOIS_COUNTRY  TCP_CONVERSATION_EXCHANGE  DIST_REMOTE_TCP_PORT  REMOTE_IPS  \
# 0              4                          7                     0           2
# 1              4                         17                     7           4
# 2              4                          0                     0           0
# 3             11                         31                    22           3
# 4             11                         57                     2           5
#
#    APP_BYTES  SOURCE_APP_PACKETS  REMOTE_APP_PACKETS  SOURCE_APP_BYTES  \
# 0        700                   9                  10              1153
# 1       1230                  17                  19              1265
# 2          0                   0                   0                 0
# 3       3812                  39                  37             18784
# 4       4278                  61                  62            129889
#
#    REMOTE_APP_BYTES  APP_PACKETS  DNS_QUERY_TIMES  Type
# 0               832            9              2.0     1
# 1              1230           17              0.0     0
# 2                 0            0              0.0     0
# 3              4380           39              8.0     0
# 4              4586           61              4.0     0
#
# Diccionario de mapeo:
# {'CHARSET': {'ISO-8859': 1, 'ISO-8859-1': 2, 'UTF-8': 3, 'iso-8859-1': 4, 'us-ascii': 5, 'utf-8': 6, 'windows-1251': 7, 'windows-1252': 8, nan: 9}, 'SERVER': {'Apache': 1, 'Microsoft': 2, 'Nginx': 3, 'Other': 4}, 'WHOIS_COUNTRY': {'AU': 1, 'CA': 2, 'CN': 3, 'Desconocido': 4, 'ES': 5, 'IN': 6, 'JP': 7, 'OTHER': 8, 'PA': 9, 'UK': 10, 'US': 11}}
#
# Tipos de datos de cada columna en website_dummy:
# URL_LENGTH                     int64
# NUMBER_SPECIAL_CHARACTERS      int64
# CHARSET                        int64
# SERVER                         int64
# CONTENT_LENGTH               float64
# WHOIS_COUNTRY                  int64
# TCP_CONVERSATION_EXCHANGE      int64
# DIST_REMOTE_TCP_PORT           int64
# REMOTE_IPS                     int64
# APP_BYTES                      int64
# SOURCE_APP_PACKETS             int64
# REMOTE_APP_PACKETS             int64
# SOURCE_APP_BYTES               int64
# REMOTE_APP_BYTES               int64
# APP_PACKETS                    int64
# DNS_QUERY_TIMES              float64
# Type                           int64
# dtype: object

# %% [markdown]
# Ahora, inspeccione `website_dummy` para asegurarse de que los datos y tipos son los previstos - no debería haber ninguna columna categórica en este punto.

# %%
# Verificar las primeras filas del DataFrame para asegurarse de que la conversión se realizó correctamente
print("Primeras filas de website_dummy:")
print(website_dummy.head())

# Verificar el tipo de datos de cada columna para asegurarse de que no quedan columnas categóricas
print("\nTipos de datos de cada columna en website_dummy:")
print(website_dummy.dtypes)
# Out:
# Primeras filas de website_dummy:
#    URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  CHARSET  SERVER  CONTENT_LENGTH  \
# 0          16                          7        4       3           263.0
# 1          16                          6        3       1         15087.0
# 2          16                          6        5       2           324.0
# 3          17                          6        2       3           162.0
# 4          17                          6        3       4        124140.0
#
#    WHOIS_COUNTRY  TCP_CONVERSATION_EXCHANGE  DIST_REMOTE_TCP_PORT  REMOTE_IPS  \
# 0              4                          7                     0           2
# 1              4                         17                     7           4
# 2              4                          0                     0           0
# 3             11                         31                    22           3
# 4             11                         57                     2           5
#
#    APP_BYTES  SOURCE_APP_PACKETS  REMOTE_APP_PACKETS  SOURCE_APP_BYTES  \
# 0        700                   9                  10              1153
# 1       1230                  17                  19              1265
# 2          0                   0                   0                 0
# 3       3812                  39                  37             18784
# 4       4278                  61                  62            129889
#
#    REMOTE_APP_BYTES  APP_PACKETS  DNS_QUERY_TIMES  Type
# 0               832            9              2.0     1
# 1              1230           17              0.0     0
# 2                 0            0              0.0     0
# 3              4380           39              8.0     0
# 4              4586           61              4.0     0
#
# Tipos de datos de cada columna en website_dummy:
# URL_LENGTH                     int64
# NUMBER_SPECIAL_CHARACTERS      int64
# CHARSET                        int64
# SERVER                         int64
# CONTENT_LENGTH               float64
# WHOIS_COUNTRY                  int64
# TCP_CONVERSATION_EXCHANGE      int64
# DIST_REMOTE_TCP_PORT           int64
# REMOTE_IPS                     int64
# APP_BYTES                      int64
# SOURCE_APP_PACKETS             int64
# REMOTE_APP_PACKETS             int64
# SOURCE_APP_BYTES               int64
# REMOTE_APP_BYTES               int64
# APP_PACKETS                    int64
# DNS_QUERY_TIMES              float64
# Type                           int64
# dtype: object

# %%
No hemos encontrado ninguna columna categórica

# %% [markdown]
# # Desafío 6 - Modelado, predicción y evaluación
#
# Comenzaremos esta sección dividiendo los datos en train y test. **Nombra tus 4 variables `X_entrenamiento`, `X_prueba`, `y_entrenamiento` y `y_prueba`. Selecciona el 80% de los datos para entrenar y el 20% para probar.**

# %%
from sklearn.model_selection import train_test_split

X = website_dummy.drop('Type', axis=1)  # Características
y = website_dummy['Type']  # Variable objetivo

# Dividir los datos en conjunto de entrenamiento y conjunto de prueba
X_entrenamiento, X_prueba, y_entrenamiento, y_prueba = train_test_split(
    X, y, 
    test_size=0.2,  # 20% para prueba
    random_state=123  # Semilla para reproducibilidad
)

print(X_entrenamiento.shape, X_prueba.shape, y_entrenamiento.shape, y_prueba.shape)
# Out:
# (1424, 16) (357, 16) (1424,) (357,)

# %% [markdown]
# #### En este laboratorio, probaremos dos modelos diferentes y compararemos nuestros resultados.
#
# El primer modelo que utilizaremos en este laboratorio es la regresión logística. Ya hemos aprendido sobre la regresión logística como algoritmo de clasificación. En la celda de abajo, cargue `LogisticRegression` de scikit-learn e inicialice el modelo.

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression(max_iter=5000,random_state=123)

print(modelo)
# Out:
# LogisticRegression(max_iter=5000, random_state=123)

# %% [markdown]
# A continuación, ajustamos el modelo a nuestros datos de entrenamiento. Ya hemos separado nuestros datos en 4 partes. Utilízalos en tu modelo.

# %%
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression

# Verificar la cantidad de NaNs en el array
print(np.isnan(X_entrenamiento).sum())
print(np.isnan(X_prueba).sum())

# Imputar valores faltantes con la media de cada columna
imputador = SimpleImputer(strategy='mean')
X_entrenamiento = imputador.fit_transform(X_entrenamiento)
X_prueba = imputador.transform(X_prueba)

# Verificar que no hay valores faltantes después de la imputación
print(np.isnan(X_entrenamiento).sum())
print(np.isnan(X_prueba).sum())

# Inicializar y ajustar el modelo
modelo = LogisticRegression()
modelo.fit(X_entrenamiento, y_entrenamiento)
# Out:
# 0
# 0
# 0
# 0
# /home/somberkers/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Por último, importamos `confusion_matrix` y `accuracy_score` de `sklearn.metrics` y ajustamos nuestros datos de prueba. Asigna los datos ajustados a `y_pred` e imprime la matriz de confusión y la puntuación de precisión.

# %%
# Realizar predicciones en los datos de prueba
y_pred = modelo.predict(X_prueba)

# Calcular y mostrar la matriz de confusión
def plot_confusion_matrix(y_pred, y):
    plt.imshow(confusion_matrix(y, y_pred), interpolation='nearest', cmap='grey')
    plt.colorbar()
    plt.ylabel('true value')
    plt.xlabel('predicted value')
    fig = plt.gcf()
    fig.set_size_inches(9, 9)

plot_confusion_matrix(y_prueba, y_pred)
print(confusion_matrix(y_prueba, y_pred))
# Out:
# [[304   9]
#  [ 30  14]]

# %%
#metricas
precisión_general = accuracy_score(y_prueba, y_pred)
precisión_positiva = precision_score(y_prueba, y_pred)
sensibilidad = recall_score(y_prueba, y_pred)
puntuación_f1 = f1_score(y_prueba, y_pred)


print(f"\nPrecisión General: {precisión_general:.2f}")
print(f"Precisión Positiva: {precisión_positiva:.2f}")
print(f"Sensibilidad: {sensibilidad:.2f}")
print(f"Puntuación F1: {puntuación_f1:.2f}")
# Out:
# Precisión General: 0.89
# Precisión Positiva: 0.61
# Sensibilidad: 0.32
# Puntuación F1: 0.42

# %% [markdown]
# ¿Qué opinas del rendimiento del modelo? Escribe tus conclusiones a continuación.

# %% [markdown]
# En resumen, aunque el modelo tiene una alta precisión general, presenta debilidades significativas en sensibilidad y precisión positiva. Estas debilidades podrían ser especialmente críticas si la identificación precisa de casos positivos es importante para la aplicación. Es recomendable ajustar el modelo, explorar técnicas adicionales o considerar modelos alternativos para mejorar la sensibilidad y precisión positiva.

# %% [markdown]
# ### Conclusiones:

# %% [markdown]
# #### Nuestro segundo algoritmo es DecisionTreeClassifier
#
# Aunque no es necesario, vamos a ajustar un modelo utilizando los datos de entrenamiento y luego probar el rendimiento del modelo utilizando los datos de prueba. Empezaremos cargando `DecisionTreeClassifier` de scikit-learn y luego inicializando y ajustando el modelo. Empezaremos con un modelo donde max_depth=3

# %%
from sklearn.tree import DecisionTreeClassifier

modelo_arbol = DecisionTreeClassifier(max_depth=3)

modelo_arbol.fit(X_entrenamiento, y_entrenamiento)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# Para probar tu modelo, calcula las probabilidades predichas, decide 0 o 1 utilizando un umbral de 0,5 e imprime la matriz de confusión, así como la puntuación de precisión (en el conjunto de prueba).

# %%
probabilidades_predichas = modelo_arbol.predict_proba(X_prueba)[:, 1]

#umbral de 0.5
umbral = 0.5
y_pred_arbol_umbral = (probabilidades_predichas >= umbral).astype(int)


matriz_confusion_arbol_umbral = confusion_matrix(y_prueba, y_pred_arbol_umbral)

# Calcular las métricas
precisión_general_arbol_umbral = accuracy_score(y_prueba, y_pred_arbol_umbral)
precisión_positiva_arbol_umbral = precision_score(y_prueba, y_pred_arbol_umbral)
sensibilidad_arbol_umbral = recall_score(y_prueba, y_pred_arbol_umbral)
puntuación_f1_arbol_umbral = f1_score(y_prueba, y_pred_arbol_umbral)


print(matriz_confusion_arbol_umbral)

print(f"\nPrecisión General: {precisión_general_arbol_umbral:.2f}")
print(f"Precisión Positiva: {precisión_positiva_arbol_umbral:.2f}")
print(f"Sensibilidad: {sensibilidad_arbol_umbral:.2f}")
print(f"Puntuación F1: {puntuación_f1_arbol_umbral:.2f}")


def plot_confusion_matrix(matriz_confusion, title='Matriz de Confusión'):
    import matplotlib.pyplot as plt
    import seaborn as sns
    plt.figure(figsize=(8, 6))
    sns.heatmap(matriz_confusion, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Predicho Negativo', 'Predicho Positivo'],
                yticklabels=['Real Negativo', 'Real Positivo'])
    plt.xlabel('Predicción')
    plt.ylabel('Real')
    plt.title(title)
    plt.show()

# Graficar la matriz de confusión
plot_confusion_matrix(matriz_confusion_arbol_umbral, title='Matriz de Confusión del Árbol de Decisión (Umbral 0.5)')
# Out:
# [[312   1]
#  [ 31  13]]
#
# Precisión General: 0.91
# Precisión Positiva: 0.93
# Sensibilidad: 0.30
# Puntuación F1: 0.45

# %% [markdown]
# #### Vamos a crear otro modelo DecisionTreeClassifier con max_depth=5.
# Inicia y ajusta el modelo de abajo e imprime la matriz de confusión y la puntuación de precisión.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# Inicializar el modelo de árbol de decisión con max_depth=5
modelo_arbol_5 = DecisionTreeClassifier(max_depth=5)

# Ajustar el modelo a los datos de entrenamiento
modelo_arbol_5.fit(X_entrenamiento, y_entrenamiento)

# Obtener las probabilidades predichas para el conjunto de prueba
probabilidades_predichas_5 = modelo_arbol_5.predict_proba(X_prueba)[:, 1]

# Decidir las predicciones utilizando un umbral de 0.5
umbral = 0.5
y_pred_arbol_5_umbral = (probabilidades_predichas_5 >= umbral).astype(int)

matriz_confusion_arbol_5_umbral = confusion_matrix(y_prueba, y_pred_arbol_5_umbral)

#las métricas
precisión_general_arbol_5_umbral = accuracy_score(y_prueba, y_pred_arbol_5_umbral)
precisión_positiva_arbol_5_umbral = precision_score(y_prueba, y_pred_arbol_5_umbral)
sensibilidad_arbol_5_umbral = recall_score(y_prueba, y_pred_arbol_5_umbral)
puntuación_f1_arbol_5_umbral = f1_score(y_prueba, y_pred_arbol_5_umbral)


print(matriz_confusion_arbol_5_umbral)

print(f"\nPrecisión General: {precisión_general_arbol_5_umbral:.2f}")
print(f"Precisión Positiva: {precisión_positiva_arbol_5_umbral:.2f}")
print(f"Sensibilidad: {sensibilidad_arbol_5_umbral:.2f}")
print(f"Puntuación F1: {puntuación_f1_arbol_5_umbral:.2f}")

# Función para graficar la matriz de confusión
def plot_confusion_matrix(matriz_confusion, title='Matriz de Confusión'):
    plt.figure(figsize=(8, 6))
    sns.heatmap(matriz_confusion, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Predicho Negativo', 'Predicho Positivo'],
                yticklabels=['Real Negativo', 'Real Positivo'])
    plt.xlabel('Predicción')
    plt.ylabel('Real')
    plt.title(title)
    plt.show()

# Graficar la matriz de confusión
plot_confusion_matrix(matriz_confusion_arbol_5_umbral, title='Matriz de Confusión del Árbol de Decisión (max_depth=5, Umbral 0.5)')
# Out:
# [[289  24]
#  [  4  40]]
#
# Precisión General: 0.92
# Precisión Positiva: 0.62
# Sensibilidad: 0.91
# Puntuación F1: 0.74

# %% [markdown]
# ¿Has observado una mejora en la matriz de confusión al aumentar max_depth a 5? ¿Has observado una mejora en la puntuación de precisión? Escribe tus conclusiones a continuación.

# %% [markdown]
# ### Conclusión:

# %% [markdown]
# Analizando los distintos valores:
#
# -Matriz de Confusion:max_depth=5 reduce los falsos positivos y aumenta los verdaderos negativos, pero también tiene más falsos negativos y menos verdaderos positivos comparado con max_depth=3.
# -Precisión General:max_depth=5 tiene una mayor precisión general (0.89 vs. 0.87), indicando una mejor capacidad global para clasificar correctamente.
# -Precisión Positiva:precisión positiva es mucho mejor con max_depth=5 (0.93 vs. 0.61), lo que significa que cuando el modelo predice positivo, es más confiable.
# -Sensibilidad:sensibilidad es ligeramente menor con max_depth=5 (0.30 vs. 0.32), sugiriendo que detecta un poco menos de casos positivos reales.
# -Puntuación F1:la puntuación F1 es ligeramente mejor con max_depth=5 (0.44 vs. 0.41), indicando un mejor equilibrio entre precisión y sensibilidad.
#
# Resumiendo: El modelo con max_depth=5 mejora la precisión general y la precisión positiva, aunque con una ligera disminución en la sensibilidad. Esto sugiere que el modelo es más confiable al clasificar positivos, pero puede perder algunos positivos reales.

# %% [markdown]
# <!-- Add your conclusion here -->

# %% [markdown]
# # Bonus Challenge - Escalado de características
#
# La resolución de problemas en el aprendizaje automático es iterativa. Puede mejorar la predicción de su modelo con diversas técnicas (aunque hay un punto óptimo para el tiempo que invierte y la mejora que obtiene). Ahora sólo has completado una iteración del análisis ML. Hay más iteraciones que puedes realizar para introducir mejoras. Para poder hacerlo, necesitarás conocimientos más profundos en estadística y dominar más técnicas de análisis de datos. En este bootcamp, no tenemos tiempo para alcanzar ese objetivo avanzado. Pero harás esfuerzos constantes después del bootcamp para conseguirlo finalmente.
#
# Sin embargo, ahora sí queremos que aprendas una de las técnicas avanzadas que se llama *feature scaling*. La idea del escalado de características es estandarizar/normalizar el rango de variables independientes o características de los datos. Esto puede hacer que los valores atípicos sean más evidentes para que pueda eliminarlos. Este paso debe realizarse durante el Desafío 6 después de dividir los datos de entrenamiento y de prueba, ya que no desea dividir los datos de nuevo, lo que hace imposible comparar los resultados con y sin el escalado de características. Para conceptos generales sobre el escalado de características, haga clic [aquí](https://en.wikipedia.org/wiki/Feature_scaling). Para profundizar, haga clic [aquí](https://medium.com/greyatom/why-how-and-when-to-scale-your-features-4b30ab09db5e).
#
# En la siguiente celda, intente mejorar la precisión de predicción de su modelo mediante el escalado de características. Una librería que puedes utilizar es `sklearn.preprocessing.RobustScaler` ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html)). Utilizarás `RobustScaler` para ajustar y transformar tu `X_train`, y luego transformar `X_test`. Utilizarás la regresión logística para ajustar y predecir tus datos transformados y obtener la puntuación de precisión de la misma manera. Compare la puntuación de precisión con sus datos normalizados con los datos de precisión anteriores. ¿Se ha producido alguna mejora?

# %%
# Your code here

# %% [markdown]
# ## Conclusiones:

# %% [markdown]
# Add your comments here:
